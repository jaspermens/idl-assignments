# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
import random
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, RNN, LSTM, Flatten, TimeDistributed, LSTMCell
from tensorflow.keras.layers import RepeatVector, Conv2D, SimpleRNN, GRU, Reshape, ConvLSTM2D, Conv2DTranspose

# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs
# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot


def decode_labels(labels):
    pred = np.argmax(labels, axis=-1)
    predicted = ''.join([unique_characters[i] for i in pred])

    return predicted

def onehot_to_integers(labels):
    argmaxes = np.argmax(labels, axis=-1)
    string_list = [''.join([unique_characters[i] for i in pred]) for pred in argmaxes]
    edge_cases = {'-  ': '100'}
    for edge_case, solution in edge_cases.items():
        string_list = [string.replace(edge_case, solution) for string in string_list]

    return np.array([int(item) for item in string_list])

# X_text_onehot = encode_labels(X_text)
# y_text_onehot = encode_labels(y_text)
# print(X_text_onehot.shape, y_text_onehot.shape)

# %%
from scipy.ndimage import rotate
# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):

    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images

def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:

    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []
                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())

                X_text.append(query_string)
                X_img.append(np.stack(query_image))
                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '
    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789* '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 4 # Maximum length of the answer string (the longest resulting query string is '99*99'='10000 - 2*99 = 10000')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer, operands=['*'])
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)


## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, image in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(image[n]), cmap='gray')
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (10000,) (10000, 5, 28, 28) (10000,) (10000, 4, 28, 28)
# ==================================================
# Query #3913
#
# X_text: "39*13" = y_text: "507 "
# ==================================================
# Query #4521
#
# X_text: "45*21" = y_text: "945 "
# ==================================================
# Query #3872
#
# X_text: "38*72" = y_text: "2736"
# ==================================================
# Query #8090
#
# X_text: "80*90" = y_text: "7200"
# ==================================================
# Query #1864
#
# X_text: "18*64" = y_text: "1152"
# ==================================================
# Query #8423
#
# X_text: "84*23" = y_text: "1932"
# ==================================================
# Query #4125
#
# X_text: "41*25" = y_text: "1025"
# ==================================================
# Query #4685
#
# X_text: "46*85" = y_text: "3910"
# ==================================================
# Query #9473
#
# X_text: "94*73" = y_text: "6862"
# ==================================================
# Query #5110
#
# X_text: "51*10" = y_text: "510 "

# %%
######################################## text2text multiplication #################################################
def build_t2t_mult_model(additional_lstm=False, additional_decoder=False):
    in_shape = (5,12)                          # Input: 5 digits
    max_answer_length = 4                      # Output: 3 digits

    # We start by initializing a sequential model
    text2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. Each of these 5 elements in the query will be fed to the network one by one,
    # as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    if additional_lstm:
        text2text.add(LSTM(256, input_shape=(None, len(unique_characters)), return_sequences=True))
        # text2text.add(LSTM(256, input_shape=in_shape, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        # text2text.add(LSTM(256, return_sequences=True))
        # text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256))

    else:
        text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))
        # text2text.add(LSTM(128, input_shape=(None, len(unique_characters))))
        # text2text.add(LSTM(256, input_shape=in_shape))
    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True))
    # text2text.add(LSTM(128, return_sequences=True))

    if additional_decoder:
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))


    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    # text2text.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # text2text.compile(loss='categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])

    text2text.summary()

    return text2text

def get_t2t_mult_split_data():
    train_cut = 7000
    val_cut = 9000
    X_text, X_img, y_text, y_img_ = create_data(highest_integer=99, operands=['*'])

    rng = np.random.default_rng(seed=123)
    indices = rng.permutation(len(y_text))
    # X_img = X_img[indices].reshape((-1, 5, 28*28))
    X_text = encode_labels(X_text[indices])
    y_text = encode_labels(y_text[indices])

    X_train, X_val, X_test = X_text[:train_cut], X_text[train_cut:val_cut], X_text[val_cut:]
    y_train, y_val, y_test = y_text[:train_cut], y_text[train_cut:val_cut], y_text[val_cut:]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# t2t_mult_model = build_t2t_mult_model()
t2t_mult_model = build_t2t_mult_model(additional_lstm=True, additional_decoder=False)
in_train, in_val, in_test, text_train, text_val, text_test = get_t2t_mult_split_data()
t2t_mult_history = t2t_mult_model.fit(in_train, text_train, epochs=100, validation_data=(in_val, text_val))             # Training: 100 epochs
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_91 (LSTM)              (None, None, 256)         275456
#
#  lstm_92 (LSTM)              (None, None, 256)         525312
#
#  lstm_93 (LSTM)              (None, None, 256)         525312
#
#  lstm_94 (LSTM)              (None, 256)               525312
#
#  repeat_vector_16 (RepeatVe  (None, 4, 256)            0
#  ctor)
#
#  lstm_95 (LSTM)              (None, 4, 256)            525312
#
#  time_distributed_16 (TimeD  (None, 4, 12)             3084
#  istributed)
#
# =================================================================
# Total params: 2379788 (9.08 MB)
# Trainable params: 2379788 (9.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 219/219 [==============================] - 14s 23ms/step - loss: 2.1506 - accuracy: 0.2130 - val_loss: 2.0217 - val_accuracy: 0.2548
# Epoch 2/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.9300 - accuracy: 0.2851 - val_loss: 1.7363 - val_accuracy: 0.3569
# Epoch 3/100
# 219/219 [==============================] - 2s 11ms/step - loss: 1.6314 - accuracy: 0.3728 - val_loss: 1.5495 - val_accuracy: 0.4017
# Epoch 4/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.4462 - accuracy: 0.4229 - val_loss: 1.3748 - val_accuracy: 0.4372
# Epoch 5/100
# 219/219 [==============================] - 3s 13ms/step - loss: 1.3417 - accuracy: 0.4547 - val_loss: 1.2622 - val_accuracy: 0.4881
# Epoch 6/100
# 219/219 [==============================] - 4s 16ms/step - loss: 1.2737 - accuracy: 0.4800 - val_loss: 1.2239 - val_accuracy: 0.4960
# Epoch 7/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.2440 - accuracy: 0.4867 - val_loss: 1.2501 - val_accuracy: 0.4779
# Epoch 8/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.1959 - accuracy: 0.5108 - val_loss: 1.2315 - val_accuracy: 0.4870
# Epoch 9/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.1669 - accuracy: 0.5191 - val_loss: 1.2084 - val_accuracy: 0.4820
# Epoch 10/100
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1284 - accuracy: 0.5361 - val_loss: 1.1328 - val_accuracy: 0.5197
# Epoch 11/100
# 219/219 [==============================] - 3s 15ms/step - loss: 1.1098 - accuracy: 0.5384 - val_loss: 1.1980 - val_accuracy: 0.4900
# Epoch 12/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.0950 - accuracy: 0.5459 - val_loss: 1.1145 - val_accuracy: 0.5249
# Epoch 13/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.0649 - accuracy: 0.5571 - val_loss: 1.1544 - val_accuracy: 0.5105
# Epoch 14/100
# 219/219 [==============================] - 3s 12ms/step - loss: 1.0421 - accuracy: 0.5685 - val_loss: 1.0492 - val_accuracy: 0.5531
# Epoch 15/100
# 219/219 [==============================] - 3s 13ms/step - loss: 1.0261 - accuracy: 0.5724 - val_loss: 1.0400 - val_accuracy: 0.5523
# Epoch 16/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.9782 - accuracy: 0.5938 - val_loss: 1.0747 - val_accuracy: 0.5412
# Epoch 17/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.9955 - accuracy: 0.5855 - val_loss: 1.0402 - val_accuracy: 0.5537
# Epoch 18/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.9454 - accuracy: 0.6070 - val_loss: 1.0094 - val_accuracy: 0.5665
# Epoch 19/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.9224 - accuracy: 0.6197 - val_loss: 0.9686 - val_accuracy: 0.5904
# Epoch 20/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.9126 - accuracy: 0.6248 - val_loss: 1.0013 - val_accuracy: 0.5729
# Epoch 21/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.8653 - accuracy: 0.6496 - val_loss: 0.9933 - val_accuracy: 0.5801
# Epoch 22/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.8537 - accuracy: 0.6539 - val_loss: 0.9521 - val_accuracy: 0.6019
# Epoch 23/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.8396 - accuracy: 0.6586 - val_loss: 0.9549 - val_accuracy: 0.5970
# Epoch 24/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.8142 - accuracy: 0.6730 - val_loss: 0.9470 - val_accuracy: 0.6039
# Epoch 25/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.7901 - accuracy: 0.6825 - val_loss: 0.9208 - val_accuracy: 0.6136
# Epoch 26/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.7700 - accuracy: 0.6938 - val_loss: 0.9300 - val_accuracy: 0.6116
# Epoch 27/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.7251 - accuracy: 0.7157 - val_loss: 0.9136 - val_accuracy: 0.6140
# Epoch 28/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.7129 - accuracy: 0.7176 - val_loss: 0.9699 - val_accuracy: 0.6071
# Epoch 29/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.6905 - accuracy: 0.7311 - val_loss: 0.9471 - val_accuracy: 0.6258
# Epoch 30/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.6627 - accuracy: 0.7451 - val_loss: 0.8832 - val_accuracy: 0.6444
# Epoch 31/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.6225 - accuracy: 0.7634 - val_loss: 0.8726 - val_accuracy: 0.6478
# Epoch 32/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.6102 - accuracy: 0.7694 - val_loss: 0.9104 - val_accuracy: 0.6425
# Epoch 33/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.6109 - accuracy: 0.7694 - val_loss: 0.9236 - val_accuracy: 0.6399
# Epoch 34/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.5556 - accuracy: 0.7964 - val_loss: 0.8690 - val_accuracy: 0.6616
# Epoch 35/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.5330 - accuracy: 0.8049 - val_loss: 0.8559 - val_accuracy: 0.6661
# Epoch 36/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.5020 - accuracy: 0.8191 - val_loss: 0.8605 - val_accuracy: 0.6710
# Epoch 37/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.5133 - accuracy: 0.8159 - val_loss: 0.8683 - val_accuracy: 0.6684
# Epoch 38/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.4596 - accuracy: 0.8404 - val_loss: 0.8581 - val_accuracy: 0.6773
# Epoch 39/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.4264 - accuracy: 0.8575 - val_loss: 0.9580 - val_accuracy: 0.6603
# Epoch 40/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.4119 - accuracy: 0.8610 - val_loss: 0.8605 - val_accuracy: 0.6905
# Epoch 41/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.3707 - accuracy: 0.8787 - val_loss: 0.8357 - val_accuracy: 0.6980
# Epoch 42/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.4080 - accuracy: 0.8644 - val_loss: 0.9268 - val_accuracy: 0.6740
# Epoch 43/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.3539 - accuracy: 0.8840 - val_loss: 0.8320 - val_accuracy: 0.7025
# Epoch 44/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.3085 - accuracy: 0.9043 - val_loss: 0.8552 - val_accuracy: 0.6988
# Epoch 45/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.3132 - accuracy: 0.8980 - val_loss: 0.8989 - val_accuracy: 0.6933
# Epoch 46/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2793 - accuracy: 0.9140 - val_loss: 0.8628 - val_accuracy: 0.7082
# Epoch 47/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2360 - accuracy: 0.9332 - val_loss: 0.8881 - val_accuracy: 0.7070
# Epoch 48/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2352 - accuracy: 0.9339 - val_loss: 0.9724 - val_accuracy: 0.6927
# Epoch 49/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.2731 - accuracy: 0.9139 - val_loss: 1.0219 - val_accuracy: 0.6821
# Epoch 50/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2372 - accuracy: 0.9308 - val_loss: 0.9940 - val_accuracy: 0.6837
# Epoch 51/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2036 - accuracy: 0.9425 - val_loss: 1.0068 - val_accuracy: 0.6965
# Epoch 52/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1733 - accuracy: 0.9559 - val_loss: 1.0038 - val_accuracy: 0.6891
# Epoch 53/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1926 - accuracy: 0.9463 - val_loss: 1.0145 - val_accuracy: 0.6935
# Epoch 54/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.1747 - accuracy: 0.9529 - val_loss: 1.0071 - val_accuracy: 0.7036
# Epoch 55/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1344 - accuracy: 0.9709 - val_loss: 0.9830 - val_accuracy: 0.7078
# Epoch 56/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1473 - accuracy: 0.9624 - val_loss: 1.1878 - val_accuracy: 0.6716
# Epoch 57/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1843 - accuracy: 0.9480 - val_loss: 1.0922 - val_accuracy: 0.6871
# Epoch 58/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.1144 - accuracy: 0.9761 - val_loss: 1.0478 - val_accuracy: 0.7071
# Epoch 59/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0749 - accuracy: 0.9904 - val_loss: 1.0054 - val_accuracy: 0.7172
# Epoch 60/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0516 - accuracy: 0.9960 - val_loss: 1.0195 - val_accuracy: 0.7181
# Epoch 61/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0433 - accuracy: 0.9979 - val_loss: 1.0390 - val_accuracy: 0.7206
# Epoch 62/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0353 - accuracy: 0.9987 - val_loss: 1.0462 - val_accuracy: 0.7185
# Epoch 63/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0310 - accuracy: 0.9991 - val_loss: 1.0698 - val_accuracy: 0.7147
# Epoch 64/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.3357 - accuracy: 0.8976 - val_loss: 1.3954 - val_accuracy: 0.6359
# Epoch 65/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2301 - accuracy: 0.9248 - val_loss: 1.1650 - val_accuracy: 0.6916
# Epoch 66/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0815 - accuracy: 0.9852 - val_loss: 1.0975 - val_accuracy: 0.7066
# Epoch 67/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0423 - accuracy: 0.9969 - val_loss: 1.0810 - val_accuracy: 0.7109
# Epoch 68/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0244 - accuracy: 0.9998 - val_loss: 1.0756 - val_accuracy: 0.7157
# Epoch 69/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0186 - accuracy: 0.9999 - val_loss: 1.0900 - val_accuracy: 0.7156
# Epoch 70/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.1048 - val_accuracy: 0.7169
# Epoch 71/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.1177 - val_accuracy: 0.7160
# Epoch 72/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.1370 - val_accuracy: 0.7139
# Epoch 73/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.1473 - val_accuracy: 0.7147
# Epoch 74/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.1637 - val_accuracy: 0.7186
# Epoch 75/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.1779 - val_accuracy: 0.7188
# Epoch 76/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.1917 - val_accuracy: 0.7181
# Epoch 77/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.2101 - val_accuracy: 0.7176
# Epoch 78/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.2217 - val_accuracy: 0.7174
# Epoch 79/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.2389 - val_accuracy: 0.7180
# Epoch 80/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.2476 - val_accuracy: 0.7200
# Epoch 81/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.2661 - val_accuracy: 0.7181
# Epoch 82/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.7678 - accuracy: 0.7951 - val_loss: 1.2917 - val_accuracy: 0.6283
# Epoch 83/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.3803 - accuracy: 0.8622 - val_loss: 1.1561 - val_accuracy: 0.6883
# Epoch 84/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.1204 - accuracy: 0.9669 - val_loss: 1.1213 - val_accuracy: 0.7078
# Epoch 85/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0435 - accuracy: 0.9960 - val_loss: 1.1349 - val_accuracy: 0.7140
# Epoch 86/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0226 - accuracy: 0.9995 - val_loss: 1.1387 - val_accuracy: 0.7161
# Epoch 87/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0155 - accuracy: 0.9996 - val_loss: 1.1661 - val_accuracy: 0.7156
# Epoch 88/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0116 - accuracy: 0.9999 - val_loss: 1.1638 - val_accuracy: 0.7211
# Epoch 89/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.1740 - val_accuracy: 0.7194
# Epoch 90/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.1910 - val_accuracy: 0.7174
# Epoch 91/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.2024 - val_accuracy: 0.7179
# Epoch 92/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.2127 - val_accuracy: 0.7200
# Epoch 93/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.2257 - val_accuracy: 0.7190
# Epoch 94/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.2375 - val_accuracy: 0.7186
# Epoch 95/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.2513 - val_accuracy: 0.7180
# Epoch 96/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.2627 - val_accuracy: 0.7188
# Epoch 97/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.2763 - val_accuracy: 0.7184
# Epoch 98/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2860 - val_accuracy: 0.7175
# Epoch 99/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3001 - val_accuracy: 0.7188
# Epoch 100/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3159 - val_accuracy: 0.7178

# %%
num = np.random.randint(0,7000,1)
print('Random number: ', num, ' X_text:', X_text[num], ' y_text:', y_text[num])
for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        #plt.title(labels[i])
        plt.imshow(np.hstack(data[num][0]), cmap='gray')
prediction = t2t_mult_model.predict(in_train[num])
print('Model prediction: ', onehot_to_integers(prediction))
# Out:
# Random number:  [396]  X_text: ['3*96 ']  y_text: ['288 ']
# 1/1 [==============================] - 1s 645ms/step
# Model prediction:  [780]

# %%
##################################### Image2text multiplication ########################################

def build_i2t_mult_model(additional_lstm=False, additional_decoder=False):
    image_shape = (5,28*28)               # Input: 5 images of 28x28 pixels
    max_answer_length = 4               # Output: 4 digits

    image2text = tf.keras.Sequential()
    if additional_lstm:
        # image2text.add(LSTM(256, input_shape=(None, len(unique_characters)), return_sequences=True))
        image2text.add(LSTM(256, input_shape=image_shape, return_sequences=True))
        image2text.add(LSTM(256, return_sequences=True))
        # image2text.add(LSTM(256, return_sequences=True))
        # image2text.add(LSTM(256, return_sequences=True))
        image2text.add(LSTM(256, return_sequences=True))
        image2text.add(LSTM(256))

    else:
        image2text.add(LSTM(256, input_shape=(None, len(unique_characters))))  # "Encode" the input images using an RNN, producing an output of size 256.
    # image2text.add(LSTM(128, input_shape=image_shape))  # "Encode" the input images using an RNN, producing an output of size 256.

    image2text.add(RepeatVector(max_answer_length))     # The RNN will always produce 3 characters as its output.
    image2text.add(LSTM(256, return_sequences=True))    # Setting return_sequences to True as TimeDistributed expects the first dimension to be the timesteps.
    # image2text.add(LSTM(128, return_sequences=True))    # Setting return_sequences to True as TimeDistributed expects the first dimension to be the timesteps.
    if additional_decoder:
        image2text.add(LSTM(256, return_sequences=True))
        image2text.add(LSTM(256, return_sequences=True))
        image2text.add(LSTM(256, return_sequences=True))

    image2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.

    # image2text.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    image2text.compile(loss='mse', optimizer='nadam', metrics=['accuracy'])

    # image2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    image2text.summary()
    return image2text

def get_i2t_mult_split_data():
    train_cut = 7000
    val_cut = 9000
    X_text, X_img, y_text, y_img_ = create_data(highest_integer=99, operands=['*'])

    rng = np.random.default_rng(seed=123)
    indices = rng.permutation(len(y_text))
    X_img = X_img[indices].reshape((-1, 5, 28*28))
    y_text = encode_labels(y_text[indices])

    X_train, X_val, X_test = X_img[:train_cut,:,:], X_img[train_cut:val_cut,:,:], X_img[val_cut:,:,:]
    y_train, y_val, y_test = y_text[:train_cut,:,:], y_text[train_cut:val_cut,:,:], y_text[val_cut:,:,:]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# i2t_mult_model = build_i2t_mult_model()
i2t_mult_model = build_i2t_mult_model(additional_lstm=True, additional_decoder=False)
im_train, im_val, im_test, text_train, text_val, text_test = get_i2t_mult_split_data()
i2t_mult_history = i2t_mult_model.fit(im_train, text_train, epochs=100, validation_data=(im_val, text_val))         # Training: 100 epochs
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_96 (LSTM)              (None, 5, 256)            1065984
#
#  lstm_97 (LSTM)              (None, 5, 256)            525312
#
#  lstm_98 (LSTM)              (None, 5, 256)            525312
#
#  lstm_99 (LSTM)              (None, 256)               525312
#
#  repeat_vector_17 (RepeatVe  (None, 4, 256)            0
#  ctor)
#
#  lstm_100 (LSTM)             (None, 4, 256)            525312
#
#  time_distributed_17 (TimeD  (None, 4, 12)             3084
#  istributed)
#
# =================================================================
# Total params: 3170316 (12.09 MB)
# Trainable params: 3170316 (12.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 219/219 [==============================] - 14s 21ms/step - loss: 0.0717 - accuracy: 0.2091 - val_loss: 0.0695 - val_accuracy: 0.2414
# Epoch 2/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0664 - accuracy: 0.2631 - val_loss: 0.0648 - val_accuracy: 0.2801
# Epoch 3/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0639 - accuracy: 0.2927 - val_loss: 0.0636 - val_accuracy: 0.2949
# Epoch 4/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0619 - accuracy: 0.3114 - val_loss: 0.0629 - val_accuracy: 0.3072
# Epoch 5/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0601 - accuracy: 0.3347 - val_loss: 0.0599 - val_accuracy: 0.3335
# Epoch 6/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0582 - accuracy: 0.3494 - val_loss: 0.0591 - val_accuracy: 0.3475
# Epoch 7/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0564 - accuracy: 0.3784 - val_loss: 0.0581 - val_accuracy: 0.3585
# Epoch 8/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0546 - accuracy: 0.3977 - val_loss: 0.0562 - val_accuracy: 0.3864
# Epoch 9/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0526 - accuracy: 0.4187 - val_loss: 0.0545 - val_accuracy: 0.4010
# Epoch 10/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0507 - accuracy: 0.4402 - val_loss: 0.0540 - val_accuracy: 0.4090
# Epoch 11/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0492 - accuracy: 0.4571 - val_loss: 0.0526 - val_accuracy: 0.4234
# Epoch 12/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0479 - accuracy: 0.4738 - val_loss: 0.0523 - val_accuracy: 0.4220
# Epoch 13/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0469 - accuracy: 0.4805 - val_loss: 0.0519 - val_accuracy: 0.4338
# Epoch 14/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0460 - accuracy: 0.4931 - val_loss: 0.0515 - val_accuracy: 0.4364
# Epoch 15/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0448 - accuracy: 0.5090 - val_loss: 0.0503 - val_accuracy: 0.4515
# Epoch 16/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0442 - accuracy: 0.5127 - val_loss: 0.0505 - val_accuracy: 0.4500
# Epoch 17/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0433 - accuracy: 0.5246 - val_loss: 0.0508 - val_accuracy: 0.4510
# Epoch 18/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0431 - accuracy: 0.5299 - val_loss: 0.0507 - val_accuracy: 0.4471
# Epoch 19/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0424 - accuracy: 0.5391 - val_loss: 0.0508 - val_accuracy: 0.4511
# Epoch 20/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0416 - accuracy: 0.5511 - val_loss: 0.0498 - val_accuracy: 0.4664
# Epoch 21/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0408 - accuracy: 0.5617 - val_loss: 0.0498 - val_accuracy: 0.4602
# Epoch 22/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0402 - accuracy: 0.5707 - val_loss: 0.0492 - val_accuracy: 0.4651
# Epoch 23/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0395 - accuracy: 0.5820 - val_loss: 0.0491 - val_accuracy: 0.4753
# Epoch 24/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0389 - accuracy: 0.5893 - val_loss: 0.0492 - val_accuracy: 0.4754
# Epoch 25/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0381 - accuracy: 0.6043 - val_loss: 0.0486 - val_accuracy: 0.4906
# Epoch 26/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0373 - accuracy: 0.6150 - val_loss: 0.0491 - val_accuracy: 0.4885
# Epoch 27/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0363 - accuracy: 0.6280 - val_loss: 0.0485 - val_accuracy: 0.4954
# Epoch 28/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0356 - accuracy: 0.6388 - val_loss: 0.0484 - val_accuracy: 0.5009
# Epoch 29/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0345 - accuracy: 0.6549 - val_loss: 0.0485 - val_accuracy: 0.5066
# Epoch 30/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0340 - accuracy: 0.6633 - val_loss: 0.0487 - val_accuracy: 0.5015
# Epoch 31/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0328 - accuracy: 0.6798 - val_loss: 0.0492 - val_accuracy: 0.5090
# Epoch 32/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0320 - accuracy: 0.6885 - val_loss: 0.0488 - val_accuracy: 0.5129
# Epoch 33/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0303 - accuracy: 0.7141 - val_loss: 0.0484 - val_accuracy: 0.5213
# Epoch 34/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0289 - accuracy: 0.7316 - val_loss: 0.0486 - val_accuracy: 0.5286
# Epoch 35/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0272 - accuracy: 0.7505 - val_loss: 0.0482 - val_accuracy: 0.5362
# Epoch 36/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0259 - accuracy: 0.7664 - val_loss: 0.0472 - val_accuracy: 0.5501
# Epoch 37/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0239 - accuracy: 0.7865 - val_loss: 0.0477 - val_accuracy: 0.5546
# Epoch 38/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0223 - accuracy: 0.8041 - val_loss: 0.0471 - val_accuracy: 0.5646
# Epoch 39/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0205 - accuracy: 0.8249 - val_loss: 0.0464 - val_accuracy: 0.5738
# Epoch 40/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0195 - accuracy: 0.8349 - val_loss: 0.0478 - val_accuracy: 0.5680
# Epoch 41/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0182 - accuracy: 0.8471 - val_loss: 0.0467 - val_accuracy: 0.5805
# Epoch 42/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0168 - accuracy: 0.8632 - val_loss: 0.0465 - val_accuracy: 0.5896
# Epoch 43/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0156 - accuracy: 0.8739 - val_loss: 0.0465 - val_accuracy: 0.5888
# Epoch 44/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0144 - accuracy: 0.8860 - val_loss: 0.0472 - val_accuracy: 0.5925
# Epoch 45/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0132 - accuracy: 0.8965 - val_loss: 0.0469 - val_accuracy: 0.5940
# Epoch 46/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0121 - accuracy: 0.9053 - val_loss: 0.0475 - val_accuracy: 0.5934
# Epoch 47/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0110 - accuracy: 0.9159 - val_loss: 0.0478 - val_accuracy: 0.5934
# Epoch 48/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0101 - accuracy: 0.9244 - val_loss: 0.0487 - val_accuracy: 0.5904
# Epoch 49/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0101 - accuracy: 0.9239 - val_loss: 0.0487 - val_accuracy: 0.5961
# Epoch 50/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0093 - accuracy: 0.9317 - val_loss: 0.0490 - val_accuracy: 0.5920
# Epoch 51/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0086 - accuracy: 0.9375 - val_loss: 0.0502 - val_accuracy: 0.5867
# Epoch 52/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0082 - accuracy: 0.9416 - val_loss: 0.0499 - val_accuracy: 0.5907
# Epoch 53/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0075 - accuracy: 0.9468 - val_loss: 0.0502 - val_accuracy: 0.5916
# Epoch 54/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0065 - accuracy: 0.9545 - val_loss: 0.0501 - val_accuracy: 0.5918
# Epoch 55/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0061 - accuracy: 0.9574 - val_loss: 0.0501 - val_accuracy: 0.5970
# Epoch 56/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0063 - accuracy: 0.9556 - val_loss: 0.0517 - val_accuracy: 0.5886
# Epoch 57/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0069 - accuracy: 0.9514 - val_loss: 0.0512 - val_accuracy: 0.5911
# Epoch 58/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0069 - accuracy: 0.9518 - val_loss: 0.0506 - val_accuracy: 0.5962
# Epoch 59/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0059 - accuracy: 0.9585 - val_loss: 0.0507 - val_accuracy: 0.6015
# Epoch 60/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0055 - accuracy: 0.9625 - val_loss: 0.0506 - val_accuracy: 0.5999
# Epoch 61/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0055 - accuracy: 0.9617 - val_loss: 0.0511 - val_accuracy: 0.5964
# Epoch 62/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0055 - accuracy: 0.9616 - val_loss: 0.0508 - val_accuracy: 0.6028
# Epoch 63/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0048 - accuracy: 0.9670 - val_loss: 0.0516 - val_accuracy: 0.5993
# Epoch 64/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0049 - accuracy: 0.9666 - val_loss: 0.0503 - val_accuracy: 0.6091
# Epoch 65/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0046 - accuracy: 0.9679 - val_loss: 0.0506 - val_accuracy: 0.6076
# Epoch 66/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0039 - accuracy: 0.9735 - val_loss: 0.0506 - val_accuracy: 0.6115
# Epoch 67/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0035 - accuracy: 0.9758 - val_loss: 0.0517 - val_accuracy: 0.6000
# Epoch 68/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0035 - accuracy: 0.9760 - val_loss: 0.0512 - val_accuracy: 0.6021
# Epoch 69/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0037 - accuracy: 0.9740 - val_loss: 0.0512 - val_accuracy: 0.6040
# Epoch 70/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0037 - accuracy: 0.9747 - val_loss: 0.0512 - val_accuracy: 0.6054
# Epoch 71/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0038 - accuracy: 0.9736 - val_loss: 0.0505 - val_accuracy: 0.6076
# Epoch 72/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0036 - accuracy: 0.9753 - val_loss: 0.0516 - val_accuracy: 0.6054
# Epoch 73/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0047 - accuracy: 0.9676 - val_loss: 0.0511 - val_accuracy: 0.6055
# Epoch 74/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0040 - accuracy: 0.9717 - val_loss: 0.0514 - val_accuracy: 0.6062
# Epoch 75/100
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0040 - accuracy: 0.9721 - val_loss: 0.0523 - val_accuracy: 0.6026
# Epoch 76/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0038 - accuracy: 0.9731 - val_loss: 0.0515 - val_accuracy: 0.6040
# Epoch 77/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0039 - accuracy: 0.9729 - val_loss: 0.0508 - val_accuracy: 0.6125
# Epoch 78/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0031 - accuracy: 0.9779 - val_loss: 0.0507 - val_accuracy: 0.6125
# Epoch 79/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0030 - accuracy: 0.9797 - val_loss: 0.0508 - val_accuracy: 0.6122
# Epoch 80/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - accuracy: 0.9801 - val_loss: 0.0516 - val_accuracy: 0.6066
# Epoch 81/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - accuracy: 0.9792 - val_loss: 0.0511 - val_accuracy: 0.6100
# Epoch 82/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0031 - accuracy: 0.9784 - val_loss: 0.0513 - val_accuracy: 0.6091
# Epoch 83/100
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0033 - accuracy: 0.9772 - val_loss: 0.0519 - val_accuracy: 0.6075
# Epoch 84/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0029 - accuracy: 0.9801 - val_loss: 0.0508 - val_accuracy: 0.6166
# Epoch 85/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - accuracy: 0.9806 - val_loss: 0.0516 - val_accuracy: 0.6125
# Epoch 86/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0034 - accuracy: 0.9762 - val_loss: 0.0519 - val_accuracy: 0.6074
# Epoch 87/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0036 - accuracy: 0.9750 - val_loss: 0.0520 - val_accuracy: 0.6077
# Epoch 88/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0033 - accuracy: 0.9772 - val_loss: 0.0512 - val_accuracy: 0.6160
# Epoch 89/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - accuracy: 0.9801 - val_loss: 0.0510 - val_accuracy: 0.6204
# Epoch 90/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0028 - accuracy: 0.9810 - val_loss: 0.0515 - val_accuracy: 0.6131
# Epoch 91/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0029 - accuracy: 0.9796 - val_loss: 0.0514 - val_accuracy: 0.6146
# Epoch 92/100
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0038 - accuracy: 0.9726 - val_loss: 0.0519 - val_accuracy: 0.6109
# Epoch 93/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0043 - accuracy: 0.9696 - val_loss: 0.0520 - val_accuracy: 0.6085
# Epoch 94/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - accuracy: 0.9795 - val_loss: 0.0512 - val_accuracy: 0.6160
# Epoch 95/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0032 - accuracy: 0.9779 - val_loss: 0.0511 - val_accuracy: 0.6140
# Epoch 96/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0027 - accuracy: 0.9816 - val_loss: 0.0511 - val_accuracy: 0.6152
# Epoch 97/100
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0024 - accuracy: 0.9833 - val_loss: 0.0515 - val_accuracy: 0.6133
# Epoch 98/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0025 - accuracy: 0.9835 - val_loss: 0.0515 - val_accuracy: 0.6158
# Epoch 99/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0025 - accuracy: 0.9825 - val_loss: 0.0521 - val_accuracy: 0.6093
# Epoch 100/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0030 - accuracy: 0.9796 - val_loss: 0.0515 - val_accuracy: 0.6149

# %%
num = np.random.randint(0,7000,1)
print('Random number: ', num, ' X_text:', X_text[num], ' y_text:', y_text[num])
for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        #plt.title(labels[i])
        plt.imshow(np.hstack(data[num][0]), cmap='gray')
prediction = i2t_mult_model.predict(im_train[num].reshape(1,5,28*28))
print('Model prediction: ', onehot_to_integers(prediction))
# Out:
# Random number:  [6145]  X_text: ['61*45']  y_text: ['2745']
# 1/1 [==============================] - 1s 891ms/step
# Model prediction:  [612]
