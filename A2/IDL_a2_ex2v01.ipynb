# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
import random
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, RNN, LSTM, Flatten, TimeDistributed, LSTMCell
from tensorflow.keras.layers import RepeatVector, Conv2D, SimpleRNN, GRU, Reshape, ConvLSTM2D, Conv2DTranspose

# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs
# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
    n = len(labels)
    length = len(labels[0])
    char_map = dict(zip(unique_characters, range(len(unique_characters))))
    one_hot = np.zeros([n, length, len(unique_characters)])
    for i, label in enumerate(labels):
        m = np.zeros([length, len(unique_characters)])
        for j, char in enumerate(label):
            m[j, char_map[char]] = 1
        one_hot[i] = m

    return one_hot


def decode_labels(labels):
    pred = np.argmax(labels, axis=-1)
    predicted = ''.join([unique_characters[i] for i in pred])

    return predicted

def onehot_to_integers(labels):
    argmaxes = np.argmax(labels, axis=-1)
    string_list = [''.join([unique_characters[i] for i in pred]) for pred in argmaxes]
    edge_cases = {'-  ': '100'}
    for edge_case, solution in edge_cases.items():
        string_list = [string.replace(edge_case, solution) for string in string_list]

    return np.array([int(item) for item in string_list])

# X_text_onehot = encode_labels(X_text)
# y_text_onehot = encode_labels(y_text)
# print(X_text_onehot.shape, y_text_onehot.shape)

# %%
from scipy.ndimage import rotate
# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):

    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images

def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:

    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []
                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())

                X_text.append(query_string)
                X_img.append(np.stack(query_image))
                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '
    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789* '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 4 # Maximum length of the answer string (the longest resulting query string is '99*99'='10000 - 2*99 = 10000')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer, operands=['*'])
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)


## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, image in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(image[n]), cmap='gray')
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (10000,) (10000, 5, 28, 28) (10000,) (10000, 4, 28, 28)
# ==================================================
# Query #6644
#
# X_text: "66*44" = y_text: "2904"
# ==================================================
# Query #965
#
# X_text: "9*65 " = y_text: "585 "
# ==================================================
# Query #29
#
# X_text: "0*29 " = y_text: "0   "
# ==================================================
# Query #4268
#
# X_text: "42*68" = y_text: "2856"
# ==================================================
# Query #9170
#
# X_text: "91*70" = y_text: "6370"
# ==================================================
# Query #5050
#
# X_text: "50*50" = y_text: "2500"
# ==================================================
# Query #201
#
# X_text: "2*1  " = y_text: "2   "
# ==================================================
# Query #659
#
# X_text: "6*59 " = y_text: "354 "
# ==================================================
# Query #656
#
# X_text: "6*56 " = y_text: "336 "
# ==================================================
# Query #4933
#
# X_text: "49*33" = y_text: "1617"

# %%
######################################## text2text multiplication #################################################
def build_t2t_mult_model(additional_lstm=False):
    in_shape = (5,12)                          # Input: 5 digits
    max_answer_length = 4                      # Output: 3 digits

    # We start by initializing a sequential model
    text2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. Each of these 5 elements in the query will be fed to the network one by one,
    # as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    if additional_lstm:
        text2text.add(LSTM(256, input_shape=(None, len(unique_characters)), return_sequences=True))
        # text2text.add(LSTM(256, input_shape=in_shape, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256, return_sequences=True))
        text2text.add(LSTM(256))

    else:
        text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))
        # text2text.add(LSTM(256, input_shape=in_shape))
    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True))

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

def get_t2t_mult_split_data():
    train_cut = 7000
    val_cut = 9000
    X_text, X_img, y_text, y_img_ = create_data(highest_integer=99, operands=['*'])

    rng = np.random.default_rng(seed=123)
    indices = rng.permutation(len(y_text))
    # X_img = X_img[indices].reshape((-1, 5, 28*28))
    X_text = encode_labels(X_text[indices])
    y_text = encode_labels(y_text[indices])

    X_train, X_val, X_test = X_text[:train_cut], X_text[train_cut:val_cut], X_text[val_cut:]
    y_train, y_val, y_test = y_text[:train_cut], y_text[train_cut:val_cut], y_text[val_cut:]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
t2t_mult_model = build_t2t_mult_model()
in_train, in_val, in_test, text_train, text_val, text_test = get_t2t_mult_split_data()
t2t_mult_history = t2t_mult_model.fit(in_train, text_train, epochs=100, validation_data=(in_val, text_val))             # Training: 100 epochs
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               275456
#
#  repeat_vector (RepeatVecto  (None, 4, 256)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 4, 256)            525312
#
#  time_distributed (TimeDist  (None, 4, 12)             3084
#  ributed)
#
# =================================================================
# Total params: 803852 (3.07 MB)
# Trainable params: 803852 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 219/219 [==============================] - 12s 10ms/step - loss: 0.0684 - accuracy: 0.2365 - val_loss: 0.0652 - val_accuracy: 0.2756
# Epoch 2/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0646 - accuracy: 0.2826 - val_loss: 0.0630 - val_accuracy: 0.3094
# Epoch 3/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0626 - accuracy: 0.3049 - val_loss: 0.0614 - val_accuracy: 0.3256
# Epoch 4/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0606 - accuracy: 0.3345 - val_loss: 0.0587 - val_accuracy: 0.3614
# Epoch 5/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0569 - accuracy: 0.3771 - val_loss: 0.0545 - val_accuracy: 0.4053
# Epoch 6/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0538 - accuracy: 0.4116 - val_loss: 0.0518 - val_accuracy: 0.4383
# Epoch 7/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0510 - accuracy: 0.4485 - val_loss: 0.0500 - val_accuracy: 0.4655
# Epoch 8/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0491 - accuracy: 0.4755 - val_loss: 0.0473 - val_accuracy: 0.4931
# Epoch 9/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0472 - accuracy: 0.4979 - val_loss: 0.0455 - val_accuracy: 0.5136
# Epoch 10/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0451 - accuracy: 0.5208 - val_loss: 0.0449 - val_accuracy: 0.5238
# Epoch 11/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0431 - accuracy: 0.5470 - val_loss: 0.0427 - val_accuracy: 0.5516
# Epoch 12/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0412 - accuracy: 0.5715 - val_loss: 0.0408 - val_accuracy: 0.5709
# Epoch 13/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0391 - accuracy: 0.5984 - val_loss: 0.0375 - val_accuracy: 0.6125
# Epoch 14/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0359 - accuracy: 0.6349 - val_loss: 0.0351 - val_accuracy: 0.6399
# Epoch 15/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0342 - accuracy: 0.6551 - val_loss: 0.0343 - val_accuracy: 0.6484
# Epoch 16/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0320 - accuracy: 0.6758 - val_loss: 0.0329 - val_accuracy: 0.6599
# Epoch 17/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0309 - accuracy: 0.6894 - val_loss: 0.0322 - val_accuracy: 0.6670
# Epoch 18/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0299 - accuracy: 0.6981 - val_loss: 0.0317 - val_accuracy: 0.6689
# Epoch 19/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0291 - accuracy: 0.7085 - val_loss: 0.0309 - val_accuracy: 0.6789
# Epoch 20/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0283 - accuracy: 0.7193 - val_loss: 0.0297 - val_accuracy: 0.6924
# Epoch 21/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0269 - accuracy: 0.7369 - val_loss: 0.0312 - val_accuracy: 0.6829
# Epoch 22/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0265 - accuracy: 0.7439 - val_loss: 0.0300 - val_accuracy: 0.6936
# Epoch 23/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0253 - accuracy: 0.7588 - val_loss: 0.0288 - val_accuracy: 0.7029
# Epoch 24/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0244 - accuracy: 0.7685 - val_loss: 0.0283 - val_accuracy: 0.7116
# Epoch 25/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0235 - accuracy: 0.7815 - val_loss: 0.0272 - val_accuracy: 0.7262
# Epoch 26/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0227 - accuracy: 0.7890 - val_loss: 0.0264 - val_accuracy: 0.7335
# Epoch 27/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0220 - accuracy: 0.7998 - val_loss: 0.0267 - val_accuracy: 0.7305
# Epoch 28/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0210 - accuracy: 0.8096 - val_loss: 0.0272 - val_accuracy: 0.7315
# Epoch 29/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0204 - accuracy: 0.8187 - val_loss: 0.0259 - val_accuracy: 0.7439
# Epoch 30/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0190 - accuracy: 0.8325 - val_loss: 0.0250 - val_accuracy: 0.7542
# Epoch 31/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.8392 - val_loss: 0.0262 - val_accuracy: 0.7426
# Epoch 32/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0173 - accuracy: 0.8517 - val_loss: 0.0243 - val_accuracy: 0.7657
# Epoch 33/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0166 - accuracy: 0.8609 - val_loss: 0.0240 - val_accuracy: 0.7699
# Epoch 34/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0154 - accuracy: 0.8723 - val_loss: 0.0236 - val_accuracy: 0.7729
# Epoch 35/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0150 - accuracy: 0.8785 - val_loss: 0.0238 - val_accuracy: 0.7731
# Epoch 36/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0142 - accuracy: 0.8867 - val_loss: 0.0230 - val_accuracy: 0.7836
# Epoch 37/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0133 - accuracy: 0.8943 - val_loss: 0.0232 - val_accuracy: 0.7805
# Epoch 38/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0124 - accuracy: 0.9030 - val_loss: 0.0227 - val_accuracy: 0.7836
# Epoch 39/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0117 - accuracy: 0.9112 - val_loss: 0.0223 - val_accuracy: 0.7921
# Epoch 40/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9165 - val_loss: 0.0227 - val_accuracy: 0.7886
# Epoch 41/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0109 - accuracy: 0.9188 - val_loss: 0.0232 - val_accuracy: 0.7866
# Epoch 42/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9251 - val_loss: 0.0226 - val_accuracy: 0.7914
# Epoch 43/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9290 - val_loss: 0.0229 - val_accuracy: 0.7883
# Epoch 44/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0090 - accuracy: 0.9365 - val_loss: 0.0218 - val_accuracy: 0.8004
# Epoch 45/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9443 - val_loss: 0.0228 - val_accuracy: 0.7951
# Epoch 46/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9485 - val_loss: 0.0218 - val_accuracy: 0.8035
# Epoch 47/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0074 - accuracy: 0.9476 - val_loss: 0.0216 - val_accuracy: 0.8052
# Epoch 48/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9592 - val_loss: 0.0212 - val_accuracy: 0.8095
# Epoch 49/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9645 - val_loss: 0.0214 - val_accuracy: 0.8080
# Epoch 50/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0062 - accuracy: 0.9594 - val_loss: 0.0225 - val_accuracy: 0.7989
# Epoch 51/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9658 - val_loss: 0.0213 - val_accuracy: 0.8142
# Epoch 52/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0047 - accuracy: 0.9715 - val_loss: 0.0220 - val_accuracy: 0.8035
# Epoch 53/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0044 - accuracy: 0.9742 - val_loss: 0.0223 - val_accuracy: 0.8014
# Epoch 54/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0042 - accuracy: 0.9747 - val_loss: 0.0221 - val_accuracy: 0.8058
# Epoch 55/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0048 - accuracy: 0.9699 - val_loss: 0.0232 - val_accuracy: 0.7975
# Epoch 56/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0037 - accuracy: 0.9784 - val_loss: 0.0215 - val_accuracy: 0.8111
# Epoch 57/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.9820 - val_loss: 0.0216 - val_accuracy: 0.8116
# Epoch 58/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0026 - accuracy: 0.9856 - val_loss: 0.0210 - val_accuracy: 0.8154
# Epoch 59/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0029 - accuracy: 0.9832 - val_loss: 0.0247 - val_accuracy: 0.7862
# Epoch 60/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0034 - accuracy: 0.9806 - val_loss: 0.0215 - val_accuracy: 0.8158
# Epoch 61/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0023 - accuracy: 0.9868 - val_loss: 0.0218 - val_accuracy: 0.8127
# Epoch 62/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0020 - accuracy: 0.9889 - val_loss: 0.0215 - val_accuracy: 0.8161
# Epoch 63/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9895 - val_loss: 0.0227 - val_accuracy: 0.8059
# Epoch 64/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0016 - accuracy: 0.9909 - val_loss: 0.0213 - val_accuracy: 0.8177
# Epoch 65/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0017 - accuracy: 0.9904 - val_loss: 0.0222 - val_accuracy: 0.8120
# Epoch 66/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0026 - accuracy: 0.9846 - val_loss: 0.0244 - val_accuracy: 0.7931
# Epoch 67/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0054 - accuracy: 0.9629 - val_loss: 0.0233 - val_accuracy: 0.8040
# Epoch 68/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.9818 - val_loss: 0.0231 - val_accuracy: 0.8083
# Epoch 69/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0021 - accuracy: 0.9871 - val_loss: 0.0223 - val_accuracy: 0.8106
# Epoch 70/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0012 - accuracy: 0.9928 - val_loss: 0.0209 - val_accuracy: 0.8253
# Epoch 71/100
# 219/219 [==============================] - 2s 8ms/step - loss: 8.4235e-04 - accuracy: 0.9944 - val_loss: 0.0210 - val_accuracy: 0.8229
# Epoch 72/100
# 219/219 [==============================] - 2s 9ms/step - loss: 7.3015e-04 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 0.8248
# Epoch 73/100
# 219/219 [==============================] - 2s 7ms/step - loss: 6.9035e-04 - accuracy: 0.9951 - val_loss: 0.0209 - val_accuracy: 0.8235
# Epoch 74/100
# 219/219 [==============================] - 1s 6ms/step - loss: 6.1630e-04 - accuracy: 0.9955 - val_loss: 0.0211 - val_accuracy: 0.8224
# Epoch 75/100
# 219/219 [==============================] - 2s 7ms/step - loss: 5.8655e-04 - accuracy: 0.9958 - val_loss: 0.0210 - val_accuracy: 0.8220
# Epoch 76/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0047 - accuracy: 0.9637 - val_loss: 0.0301 - val_accuracy: 0.7490
# Epoch 77/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0053 - accuracy: 0.9609 - val_loss: 0.0227 - val_accuracy: 0.8085
# Epoch 78/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0013 - accuracy: 0.9932 - val_loss: 0.0210 - val_accuracy: 0.8240
# Epoch 79/100
# 219/219 [==============================] - 1s 7ms/step - loss: 6.7609e-04 - accuracy: 0.9960 - val_loss: 0.0207 - val_accuracy: 0.8271
# Epoch 80/100
# 219/219 [==============================] - 2s 9ms/step - loss: 5.2896e-04 - accuracy: 0.9964 - val_loss: 0.0207 - val_accuracy: 0.8296
# Epoch 81/100
# 219/219 [==============================] - 2s 9ms/step - loss: 4.7384e-04 - accuracy: 0.9964 - val_loss: 0.0208 - val_accuracy: 0.8289
# Epoch 82/100
# 219/219 [==============================] - 2s 8ms/step - loss: 4.4925e-04 - accuracy: 0.9966 - val_loss: 0.0207 - val_accuracy: 0.8280
# Epoch 83/100
# 219/219 [==============================] - 2s 7ms/step - loss: 4.2460e-04 - accuracy: 0.9967 - val_loss: 0.0208 - val_accuracy: 0.8275
# Epoch 84/100
# 219/219 [==============================] - 1s 7ms/step - loss: 4.1179e-04 - accuracy: 0.9969 - val_loss: 0.0209 - val_accuracy: 0.8278
# Epoch 85/100
# 219/219 [==============================] - 1s 7ms/step - loss: 3.8722e-04 - accuracy: 0.9970 - val_loss: 0.0209 - val_accuracy: 0.8271
# Epoch 86/100
# 219/219 [==============================] - 2s 7ms/step - loss: 3.7029e-04 - accuracy: 0.9971 - val_loss: 0.0208 - val_accuracy: 0.8281
# Epoch 87/100
# 219/219 [==============================] - 1s 7ms/step - loss: 5.3121e-04 - accuracy: 0.9961 - val_loss: 0.0239 - val_accuracy: 0.8043
# Epoch 88/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9310 - val_loss: 0.0254 - val_accuracy: 0.7896
# Epoch 89/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0035 - accuracy: 0.9770 - val_loss: 0.0225 - val_accuracy: 0.8140
# Epoch 90/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0011 - accuracy: 0.9939 - val_loss: 0.0219 - val_accuracy: 0.8209
# Epoch 91/100
# 219/219 [==============================] - 2s 7ms/step - loss: 7.3486e-04 - accuracy: 0.9960 - val_loss: 0.0209 - val_accuracy: 0.8290
# Epoch 92/100
# 219/219 [==============================] - 2s 7ms/step - loss: 4.3999e-04 - accuracy: 0.9971 - val_loss: 0.0208 - val_accuracy: 0.8292
# Epoch 93/100
# 219/219 [==============================] - 1s 7ms/step - loss: 3.8334e-04 - accuracy: 0.9971 - val_loss: 0.0206 - val_accuracy: 0.8298
# Epoch 94/100
# 219/219 [==============================] - 2s 7ms/step - loss: 3.4552e-04 - accuracy: 0.9973 - val_loss: 0.0206 - val_accuracy: 0.8313
# Epoch 95/100
# 219/219 [==============================] - 2s 7ms/step - loss: 3.2706e-04 - accuracy: 0.9975 - val_loss: 0.0206 - val_accuracy: 0.8324
# Epoch 96/100
# 219/219 [==============================] - 2s 7ms/step - loss: 3.1128e-04 - accuracy: 0.9975 - val_loss: 0.0206 - val_accuracy: 0.8320
# Epoch 97/100
# 219/219 [==============================] - 2s 9ms/step - loss: 3.0397e-04 - accuracy: 0.9976 - val_loss: 0.0206 - val_accuracy: 0.8328
# Epoch 98/100
# 219/219 [==============================] - 2s 9ms/step - loss: 2.9478e-04 - accuracy: 0.9976 - val_loss: 0.0206 - val_accuracy: 0.8316
# Epoch 99/100
# 219/219 [==============================] - 1s 6ms/step - loss: 2.9034e-04 - accuracy: 0.9976 - val_loss: 0.0205 - val_accuracy: 0.8338
# Epoch 100/100
# 219/219 [==============================] - 1s 6ms/step - loss: 2.8567e-04 - accuracy: 0.9976 - val_loss: 0.0206 - val_accuracy: 0.8335

# %%
num = np.random.randint(0,7000,1)
print('Random number: ', num, ' X_text:', X_text[num], ' y_text:', y_text[num])
for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        #plt.title(labels[i])
        plt.imshow(np.hstack(data[num][0]), cmap='gray')
prediction = t2t_mult_model.predict(in_train[num])
print('Model prediction: ', onehot_to_integers(prediction))
# Out:
# Random number:  [396]  X_text: ['3*96 ']  y_text: ['288 ']
# 1/1 [==============================] - 1s 645ms/step
# Model prediction:  [780]

# %%
##################################### Image2text multiplication ########################################

def build_i2t_mult_model():
    image_shape = (5,784)               # Input: 5 images of 28x28 pixels
    max_answer_length = 4               # Output: 4 digits

    image2text = tf.keras.Sequential()
    image2text.add(LSTM(256, input_shape=image_shape))  # "Encode" the input images using an RNN, producing an output of size 256.
    image2text.add(RepeatVector(max_answer_length))     # The RNN will always produce 3 characters as its output.
    image2text.add(LSTM(256, return_sequences=True))    # Setting return_sequences to True as TimeDistributed expects the first dimension to be the timesteps.
    image2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.

    image2text.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    image2text.summary()
    return image2text

def get_i2t_mult_split_data():
    train_cut = 7000
    val_cut = 9000
    X_text, X_img, y_text, y_img_ = create_data(highest_integer=99, operands=['*'])

    rng = np.random.default_rng(seed=123)
    indices = rng.permutation(len(y_text))
    X_img = X_img[indices].reshape((-1, 5, 28*28))
    y_text = encode_labels(y_text[indices])

    X_train, X_val, X_test = X_img[:train_cut,:,:], X_img[train_cut:val_cut,:,:], X_img[val_cut:,:,:]
    y_train, y_val, y_test = y_text[:train_cut,:,:], y_text[train_cut:val_cut,:,:], y_text[val_cut:,:,:]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
i2t_mult_model = build_i2t_mult_model()
im_train, im_val, im_test, text_train, text_val, text_test = get_i2t_mult_split_data()
i2t_mult_history = i2t_mult_model.fit(im_train, text_train, epochs=100, validation_data=(im_val, text_val))         # Training: 100 epochs
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 256)               1065984
#
#  repeat_vector_1 (RepeatVec  (None, 4, 256)            0
#  tor)
#
#  lstm_3 (LSTM)               (None, 4, 256)            525312
#
#  time_distributed_1 (TimeDi  (None, 4, 12)             3084
#  stributed)
#
# =================================================================
# Total params: 1594380 (6.08 MB)
# Trainable params: 1594380 (6.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 219/219 [==============================] - 7s 13ms/step - loss: 0.0690 - accuracy: 0.2345 - val_loss: 0.0665 - val_accuracy: 0.2688
# Epoch 2/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0655 - accuracy: 0.2809 - val_loss: 0.0649 - val_accuracy: 0.2880
# Epoch 3/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0631 - accuracy: 0.3093 - val_loss: 0.0618 - val_accuracy: 0.3226
# Epoch 4/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0604 - accuracy: 0.3358 - val_loss: 0.0606 - val_accuracy: 0.3329
# Epoch 5/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0582 - accuracy: 0.3625 - val_loss: 0.0597 - val_accuracy: 0.3456
# Epoch 6/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0561 - accuracy: 0.3871 - val_loss: 0.0592 - val_accuracy: 0.3573
# Epoch 7/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0541 - accuracy: 0.4144 - val_loss: 0.0595 - val_accuracy: 0.3587
# Epoch 8/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0521 - accuracy: 0.4460 - val_loss: 0.0592 - val_accuracy: 0.3634
# Epoch 9/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0497 - accuracy: 0.4814 - val_loss: 0.0596 - val_accuracy: 0.3750
# Epoch 10/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0471 - accuracy: 0.5190 - val_loss: 0.0597 - val_accuracy: 0.3719
# Epoch 11/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0441 - accuracy: 0.5553 - val_loss: 0.0600 - val_accuracy: 0.3857
# Epoch 12/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0408 - accuracy: 0.5967 - val_loss: 0.0606 - val_accuracy: 0.3931
# Epoch 13/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0376 - accuracy: 0.6348 - val_loss: 0.0616 - val_accuracy: 0.3913
# Epoch 14/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0349 - accuracy: 0.6652 - val_loss: 0.0630 - val_accuracy: 0.3909
# Epoch 15/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0324 - accuracy: 0.6982 - val_loss: 0.0638 - val_accuracy: 0.3920
# Epoch 16/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0293 - accuracy: 0.7314 - val_loss: 0.0647 - val_accuracy: 0.3936
# Epoch 17/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0268 - accuracy: 0.7608 - val_loss: 0.0663 - val_accuracy: 0.3964
# Epoch 18/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0241 - accuracy: 0.7890 - val_loss: 0.0671 - val_accuracy: 0.3904
# Epoch 19/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0218 - accuracy: 0.8139 - val_loss: 0.0687 - val_accuracy: 0.3866
# Epoch 20/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0191 - accuracy: 0.8420 - val_loss: 0.0704 - val_accuracy: 0.3875
# Epoch 21/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.8648 - val_loss: 0.0706 - val_accuracy: 0.3906
# Epoch 22/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0147 - accuracy: 0.8827 - val_loss: 0.0719 - val_accuracy: 0.3898
# Epoch 23/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0130 - accuracy: 0.8989 - val_loss: 0.0729 - val_accuracy: 0.3914
# Epoch 24/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0112 - accuracy: 0.9145 - val_loss: 0.0734 - val_accuracy: 0.3925
# Epoch 25/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0101 - accuracy: 0.9225 - val_loss: 0.0738 - val_accuracy: 0.3886
# Epoch 26/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0091 - accuracy: 0.9323 - val_loss: 0.0741 - val_accuracy: 0.3943
# Epoch 27/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0077 - accuracy: 0.9425 - val_loss: 0.0748 - val_accuracy: 0.3955
# Epoch 28/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9487 - val_loss: 0.0755 - val_accuracy: 0.3926
# Epoch 29/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9544 - val_loss: 0.0757 - val_accuracy: 0.3966
# Epoch 30/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0057 - accuracy: 0.9573 - val_loss: 0.0764 - val_accuracy: 0.3879
# Epoch 31/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9574 - val_loss: 0.0769 - val_accuracy: 0.3934
# Epoch 32/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0057 - accuracy: 0.9583 - val_loss: 0.0774 - val_accuracy: 0.3926
# Epoch 33/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9592 - val_loss: 0.0774 - val_accuracy: 0.3902
# Epoch 34/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0054 - accuracy: 0.9602 - val_loss: 0.0773 - val_accuracy: 0.3934
# Epoch 35/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9603 - val_loss: 0.0778 - val_accuracy: 0.3909
# Epoch 36/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0051 - accuracy: 0.9631 - val_loss: 0.0777 - val_accuracy: 0.3943
# Epoch 37/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0043 - accuracy: 0.9686 - val_loss: 0.0776 - val_accuracy: 0.3952
# Epoch 38/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0036 - accuracy: 0.9724 - val_loss: 0.0782 - val_accuracy: 0.3900
# Epoch 39/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0036 - accuracy: 0.9726 - val_loss: 0.0778 - val_accuracy: 0.3954
# Epoch 40/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0042 - accuracy: 0.9694 - val_loss: 0.0788 - val_accuracy: 0.3925
# Epoch 41/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0043 - accuracy: 0.9684 - val_loss: 0.0797 - val_accuracy: 0.3891
# Epoch 42/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0044 - accuracy: 0.9679 - val_loss: 0.0796 - val_accuracy: 0.3882
# Epoch 43/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0043 - accuracy: 0.9690 - val_loss: 0.0798 - val_accuracy: 0.3874
# Epoch 44/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0042 - accuracy: 0.9696 - val_loss: 0.0793 - val_accuracy: 0.3935
# Epoch 45/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0037 - accuracy: 0.9728 - val_loss: 0.0795 - val_accuracy: 0.3884
# Epoch 46/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0031 - accuracy: 0.9765 - val_loss: 0.0794 - val_accuracy: 0.3907
# Epoch 47/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.9756 - val_loss: 0.0797 - val_accuracy: 0.3882
# Epoch 48/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.9763 - val_loss: 0.0799 - val_accuracy: 0.3915
# Epoch 49/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.9769 - val_loss: 0.0799 - val_accuracy: 0.3905
# Epoch 50/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0034 - accuracy: 0.9747 - val_loss: 0.0814 - val_accuracy: 0.3830
# Epoch 51/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0032 - accuracy: 0.9762 - val_loss: 0.0803 - val_accuracy: 0.3926
# Epoch 52/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.9758 - val_loss: 0.0801 - val_accuracy: 0.3929
# Epoch 53/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.9772 - val_loss: 0.0805 - val_accuracy: 0.3906
# Epoch 54/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0034 - accuracy: 0.9752 - val_loss: 0.0806 - val_accuracy: 0.3898
# Epoch 55/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0042 - accuracy: 0.9690 - val_loss: 0.0807 - val_accuracy: 0.3940
# Epoch 56/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0032 - accuracy: 0.9766 - val_loss: 0.0799 - val_accuracy: 0.3952
# Epoch 57/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.9793 - val_loss: 0.0796 - val_accuracy: 0.3974
# Epoch 58/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0026 - accuracy: 0.9801 - val_loss: 0.0800 - val_accuracy: 0.3960
# Epoch 59/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0024 - accuracy: 0.9816 - val_loss: 0.0803 - val_accuracy: 0.3935
# Epoch 60/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0025 - accuracy: 0.9813 - val_loss: 0.0806 - val_accuracy: 0.3905
# Epoch 61/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0026 - accuracy: 0.9803 - val_loss: 0.0816 - val_accuracy: 0.3868
# Epoch 62/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.9793 - val_loss: 0.0816 - val_accuracy: 0.3887
# Epoch 63/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.9786 - val_loss: 0.0815 - val_accuracy: 0.3877
# Epoch 64/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0036 - accuracy: 0.9737 - val_loss: 0.0814 - val_accuracy: 0.3871
# Epoch 65/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.9762 - val_loss: 0.0811 - val_accuracy: 0.3905
# Epoch 66/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.9791 - val_loss: 0.0813 - val_accuracy: 0.3890
# Epoch 67/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.9798 - val_loss: 0.0815 - val_accuracy: 0.3900
# Epoch 68/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0027 - accuracy: 0.9799 - val_loss: 0.0819 - val_accuracy: 0.3870
# Epoch 69/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0026 - accuracy: 0.9808 - val_loss: 0.0808 - val_accuracy: 0.3981
# Epoch 70/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0024 - accuracy: 0.9820 - val_loss: 0.0822 - val_accuracy: 0.3839
# Epoch 71/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0026 - accuracy: 0.9808 - val_loss: 0.0813 - val_accuracy: 0.3990
# Epoch 72/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0026 - accuracy: 0.9813 - val_loss: 0.0815 - val_accuracy: 0.3923
# Epoch 73/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0028 - accuracy: 0.9789 - val_loss: 0.0819 - val_accuracy: 0.3871
# Epoch 74/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.9788 - val_loss: 0.0812 - val_accuracy: 0.3959
# Epoch 75/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0027 - accuracy: 0.9801 - val_loss: 0.0817 - val_accuracy: 0.3934
# Epoch 76/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0024 - accuracy: 0.9822 - val_loss: 0.0815 - val_accuracy: 0.3932
# Epoch 77/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0022 - accuracy: 0.9834 - val_loss: 0.0811 - val_accuracy: 0.3976
# Epoch 78/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0020 - accuracy: 0.9846 - val_loss: 0.0815 - val_accuracy: 0.3944
# Epoch 79/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0020 - accuracy: 0.9849 - val_loss: 0.0813 - val_accuracy: 0.3935
# Epoch 80/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0023 - accuracy: 0.9826 - val_loss: 0.0821 - val_accuracy: 0.3880
# Epoch 81/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.9781 - val_loss: 0.0822 - val_accuracy: 0.3891
# Epoch 82/100
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0029 - accuracy: 0.9779 - val_loss: 0.0827 - val_accuracy: 0.3862
# Epoch 83/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0028 - accuracy: 0.9798 - val_loss: 0.0818 - val_accuracy: 0.3896
# Epoch 84/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0026 - accuracy: 0.9808 - val_loss: 0.0826 - val_accuracy: 0.3857
# Epoch 85/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0026 - accuracy: 0.9807 - val_loss: 0.0827 - val_accuracy: 0.3860
# Epoch 86/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0023 - accuracy: 0.9829 - val_loss: 0.0822 - val_accuracy: 0.3929
# Epoch 87/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0021 - accuracy: 0.9845 - val_loss: 0.0817 - val_accuracy: 0.3916
# Epoch 88/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0020 - accuracy: 0.9852 - val_loss: 0.0824 - val_accuracy: 0.3945
# Epoch 89/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0019 - accuracy: 0.9858 - val_loss: 0.0817 - val_accuracy: 0.3950
# Epoch 90/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0018 - accuracy: 0.9861 - val_loss: 0.0821 - val_accuracy: 0.3919
# Epoch 91/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0018 - accuracy: 0.9864 - val_loss: 0.0829 - val_accuracy: 0.3865
# Epoch 92/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9864 - val_loss: 0.0827 - val_accuracy: 0.3891
# Epoch 93/100
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0025 - accuracy: 0.9813 - val_loss: 0.0833 - val_accuracy: 0.3879
# Epoch 94/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0040 - accuracy: 0.9695 - val_loss: 0.0834 - val_accuracy: 0.3845
# Epoch 95/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0035 - accuracy: 0.9743 - val_loss: 0.0822 - val_accuracy: 0.3916
# Epoch 96/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0027 - accuracy: 0.9802 - val_loss: 0.0832 - val_accuracy: 0.3862
# Epoch 97/100
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0022 - accuracy: 0.9837 - val_loss: 0.0832 - val_accuracy: 0.3871
# Epoch 98/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0019 - accuracy: 0.9856 - val_loss: 0.0825 - val_accuracy: 0.3924
# Epoch 99/100
# 219/219 [==============================] - 1s 7ms/step - loss: 0.0019 - accuracy: 0.9859 - val_loss: 0.0830 - val_accuracy: 0.3875
# Epoch 100/100
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0018 - accuracy: 0.9866 - val_loss: 0.0832 - val_accuracy: 0.3868

# %%
num = np.random.randint(0,7000,1)
print('Random number: ', num, ' X_text:', X_text[num], ' y_text:', y_text[num])
for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        #plt.title(labels[i])
        plt.imshow(np.hstack(data[num][0]), cmap='gray')
prediction = i2t_mult_model.predict(im_train[num].reshape(1,5,28*28))
print('Model prediction: ', onehot_to_integers(prediction))
# Out:
# Random number:  [6145]  X_text: ['61*45']  y_text: ['2745']
# 1/1 [==============================] - 1s 891ms/step
# Model prediction:  [612]
